# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Learning FourSquare API with Python</font></h1>

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, you will learn how to use the visualization library, Folium, to visualize the results.

# %% [markdown]
# ## Table of Contents
#
# 1.  <a href="#item1">Foursquare API Search Function</a>
# 2.  <a href="#item2">Explore a Given Venue</a>
# 3.  <a href="#item3">Explore a User</a>
# 4.  <a href="#item4">Foursquare API Explore Function</a>
# 5.  <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %% [markdown]
# ##### To obtain access token follow these steps.
#
# <br>
#
# 1.  Go to your **"App Settings"** page on the developer console of Foursquare.com
# 2.  Set the **"Redirect URL"** under **"Web Addresses"** to [https://www.google.com](https://www.google.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
#
# 3.  Paste and enter the following url in your web browser **(replace YOUR_CLIENT_ID with your actual client id)**:
#     [https://foursquare.com/oauth2/authenticate?client_id=YOUR_CLIENT_ID&response_type=code&redirect_uri=https://www.google.com](https://foursquare.com/oauth2/authenticate?client_id=YOUR_CLIENT_ID&response_type=code&redirect_uri=https://www.google.com&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
#     This should redirect you to a google page requesting permission to make the connection.
# 4.  Accept and then look at the url of your web browser **(take note at the CODE part of the url to use in step 5)**
#     It should look like [https://www.google.com/?code=CODE](https://www.google.com?code=CODE&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
# 5.  Copy the code value from the previous step.
#        Paste and enter the following into your web browser **(replace placeholders with actual values)**:
#     [https://foursquare.com/oauth2/access_token?client_id=YOUR_CLIENT_ID&client_secret=YOUR_CLIENT_SECRET&grant_type=authorization_code&redirect_uri=https://www.google.com&code=CODE](https://foursquare.com/oauth2/access_token?client_id=YOUR_CLIENT_ID&client_secret=YOUR_CLIENT_SECRET&grant_type=authorization_code&redirect_uri=https://www.google.com&code=CODE&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
# 6.  When you paste the link , This should lead you to a page that gives you your **access token**.

# %%
CLIENT_ID = 'AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1' # your Foursquare ID
CLIENT_SECRET = 'XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL' # your Foursquare Secret
ACCESS_TOKEN = 'JVP0CYFI0X1O2S21N44G1I303FDAJBY1ZJUI0X0YRVLVJQRE' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

#https://foursquare.com/oauth2/authenticate?client_id=AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1&response_type=code&redirect_uri=https://www.google.com

#https://www.google.com/#access_token=JVP0CYFI0X1O2S21N44G1I303FDAJBY1ZJUI0X0YRVLVJQRE

#Link for easier method https://stackoverflow.com/questions/45432268/how-do-i-get-access-token-from-foursquare
# Out:
# Your credentails:
# CLIENT_ID: AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1
# CLIENT_SECRET:XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '405 K St, Sacramento, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

#https://api.foursquare.com/v2/venues/search?client_id=AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1&client_secret=XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL&ll=40.7149555,-74.0153365&v=VERSION&query=QUERY&radius=RADIUS&limit=LIMIT
# Out:
# 38.58137029292929 -121.50181023232324

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
#
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'Coffee'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1&client_secret=XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL&ll=38.58137029292929,-121.50181023232324&oauth_token=JVP0CYFI0X1O2S21N44G1I303FDAJBY1ZJUI0X0YRVLVJQRE&v=20180604&query=Coffee&radius=2000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60696b948cf9a179840c68ab'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4b5dbd50f964a5204d6929e3',
#     'name': 'Temple Coffee & Tea',
#     'location': {'address': '1010 9th St',
#      'crossStreet': 'btwn J & K St',
#      'lat': 38.58041379940968,
#      'lng': -121.49503550282543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58041379940968,
#        'lng': -121.49503550282543}],
#      'distance': 599,
#      'postalCode': '95814',
#      'cc': 'US',
#      'neighborhood': 'Downtown Sacramento',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1010 9th St (btwn J & K St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '528cddfc11d2c7ab7a3c9e61',
#     'name': 'Capitol Coffee',
#     'location': {'address': '1303 10th St',
#      'lat': 38.57678985595703,
#      'lng': -121.49482727050781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57678985595703,
#        'lng': -121.49482727050781}],
#      'distance': 793,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1303 10th St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5a7f2b1b646e3832bf90475c',
#     'name': 'Camellia Coffee Roasters',
#     'location': {'address': '1104 R St Ste 150',
#      'crossStreet': 'at 11th St',
#      'lat': 38.57072738788299,
#      'lng': -121.49552822113036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57072738788299,
#        'lng': -121.49552822113036}],
#      'distance': 1304,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1104 R St Ste 150 (at 11th St)',
#       'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5d6ea8b657ba4900081b5b77',
#     'name': 'Roots Coffee',
#     'location': {'address': '428 J St Ste 120',
#      'crossStreet': 'at 5th St',
#      'lat': 38.581802,
#      'lng': -121.50038,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.581802,
#        'lng': -121.50038}],
#      'distance': 133,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 J St Ste 120 (at 5th St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5d335a7857c4ad00089607c5',
#     'name': 'Temple Coffee Roasters',
#     'location': {'address': '1615 16th St',
#      'crossStreet': 'at Powerhouse Aly',
#      'lat': 38.57099,
#      'lng': -121.488106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57099,
#        'lng': -121.488106}],
#      'distance': 1660,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1615 16th St (at Powerhouse Aly)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2040030',
#      'url': 'https://www.grubhub.com/restaurant/temple-coffee-roasters-1615-16th-st-sacramento/2040030?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2040030',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '507ed58ee4b0105cdae3110e',
#     'name': 'Shine - Coffee | Art | Music',
#     'location': {'address': '1400 E St',
#      'crossStreet': 'at 14th St',
#      'lat': 38.58410674401821,
#      'lng': -121.48542689451259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58410674401821,
#        'lng': -121.48542689451259}],
#      'distance': 1457,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1400 E St (at 14th St)', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '74683058'},
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4df7833d62e141c90764da81',
#     'name': 'Coffee Shoppe Building 171',
#     'location': {'address': '1501 Capitol Ave',
#      'lat': 38.57542037963867,
#      'lng': -121.48780822753906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57542037963867,
#        'lng': -121.48780822753906}],
#      'distance': 1386,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1501 Capitol Ave', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4b0aff76f964a520522b23e3',
#     'name': 'Chocolate Fish Coffee Roasters',
#     'location': {'address': '400 P St Ste 1203B',
#      'crossStreet': 'at 3rd & Q St',
#      'lat': 38.575067730078615,
#      'lng': -121.50598477403632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.575067730078615,
#        'lng': -121.50598477403632},
#       {'label': 'entrance', 'lat': 38.575663, 'lng': -121.504729}],
#      'distance': 790,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['400 P St Ste 1203B (at 3rd & Q St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4c2f9c61ed37a59384976703',
#     'name': 'Pacha Coffee / Pachamama Coffee Co-op',
#     'location': {'address': '919 20th St',
#      'crossStreet': 'btwn I & J St',
#      'lat': 38.57709162976878,
#      'lng': -121.47961824533758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57709162976878,
#        'lng': -121.47961824533758}],
#      'distance': 1989,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['919 20th St (btwn I & J St)',
#       'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4ad92c42f964a520d61821e3',
#     'name': "Peet's Coffee & Tea",
#     'location': {'address': '1050 20th St #190',
#      'crossStreet': 'at J St',
#      'lat': 38.576585,
#      'lng': -121.480161,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.576585,
#        'lng': -121.480161},
#       {'label': 'entrance', 'lat': 38.576177, 'lng': -121.480264}],
#      'distance': 1957,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1050 20th St #190 (at J St)',
#       'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '1359394722'},
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5fd50d4dae5d383597204583',
#     'name': 'Blueprint Coffee Project',
#     'location': {'address': '1200 2nd St',
#      'lat': 38.58097,
#      'lng': -121.50553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58097,
#        'lng': -121.50553}],
#      'distance': 326,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1200 2nd St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '553fd753498e429dca65be84',
#     'name': 'Turnaround Coffee House',
#     'location': {'address': '724 7th St',
#      'lat': 38.583980560302734,
#      'lng': -121.49675750732422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.583980560302734,
#        'lng': -121.49675750732422}],
#      'distance': 527,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['724 7th St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4ec2da519adf5630f7182028',
#     'name': 'Amtrak Station Coffee & Snacks',
#     'location': {'address': '401 I St',
#      'crossStreet': 'at 5th St',
#      'lat': 38.58405543065516,
#      'lng': -121.50066488080698,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58405543065516,
#        'lng': -121.50066488080698}],
#      'distance': 315,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['401 I St (at 5th St)', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'shortName': 'Train Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4bc48ec32a89ef3b8e6df688',
#     'name': 'Beanheads Coffee Cart',
#     'location': {'address': '801 K St',
#      'lat': 38.580054,
#      'lng': -121.495798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.580054,
#        'lng': -121.495798}],
#      'distance': 543,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['801 K St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '556e164d498e044287137ee0',
#     'name': 'The Buzz Coffee Brewery',
#     'location': {'address': '1121 L St',
#      'lat': 38.577901000000004,
#      'lng': -121.49226200000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.577901000000004,
#        'lng': -121.49226200000001}],
#      'distance': 916,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1121 L St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5d3c70fbb68ce90007214cff',
#     'name': 'Goodside Coffee',
#     'location': {'address': '1430 H St',
#      'crossStreet': 'at 15th St',
#      'lat': 38.580525,
#      'lng': -121.486273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.580525,
#        'lng': -121.486273}],
#      'distance': 1355,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1430 H St (at 15th St)', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4f326c6919836c91c7d666a2',
#     'name': 'Coffee and More',
#     'location': {'address': '1515 R St',
#      'lat': 38.56964111328125,
#      'lng': -121.48985290527344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.56964111328125,
#        'lng': -121.48985290527344}],
#      'distance': 1669,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1515 R St', 'Sacramento, CA 95811']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '571a5ec2498e9a18b2ea233e',
#     'name': 'Milka Coffee Roasters',
#     'location': {'address': '1501 G St',
#      'crossStreet': 'at 15th St',
#      'lat': 38.5818216608345,
#      'lng': -121.48484230041502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.5818216608345,
#        'lng': -121.48484230041502}],
#      'distance': 1477,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1501 G St (at 15th St)', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '59136bf55315932e7f2f6627',
#     'name': 'Oblivion Comics & Coffee',
#     'location': {'address': '1020 11th St',
#      'crossStreet': 'btwn J & K St',
#      'lat': 38.57933470479946,
#      'lng': -121.49249406419403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57933470479946,
#        'lng': -121.49249406419403}],
#      'distance': 841,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1020 11th St (btwn J & K St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#       'name': 'Comic Shop',
#       'pluralName': 'Comic Shops',
#       'shortName': 'Comic Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4d499ea119ab2d437a4eab95',
#     'name': 'Robot Coffee',
#     'location': {'address': '11th and C Streets',
#      'lat': 38.5871052312755,
#      'lng': -121.48887634277344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.5871052312755,
#        'lng': -121.48887634277344}],
#      'distance': 1293,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['11th and C Streets', 'Sacramento, CA 95814']},
#     'categories': [],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4b589227f964a520c35e28e3',
#     'name': 'Chicory Coffee & Tea',
#     'location': {'address': '1137 11th St',
#      'crossStreet': 'at L St',
#      'lat': 38.577852437358736,
#      'lng': -121.49290770292282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.577852437358736,
#        'lng': -121.49290770292282}],
#      'distance': 868,
#      'postalCode': '95814',
#      'cc': 'US',
#      'neighborhood': 'Downtown Sacramento',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1137 11th St (at L St)', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5f5eeed2fd76be70ad33daf0',
#     'name': 'Scorpio Coffee',
#     'location': {'address': '1905 16th St',
#      'lat': 38.567838,
#      'lng': -121.489368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.567838,
#        'lng': -121.489368}],
#      'distance': 1855,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1905 16th St', 'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '596e78d06a8d8610d1cce74d',
#     'name': 'Philz Coffee',
#     'location': {'address': '1725 R St',
#      'crossStreet': 'at 17th St',
#      'lat': 38.56896952981297,
#      'lng': -121.48711040990693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.56896952981297,
#        'lng': -121.48711040990693}],
#      'distance': 1882,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1725 R St (at 17th St)', 'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '54beab69498e7bffee036e59',
#     'name': 'Grace Coffee Roasters',
#     'location': {'address': '1215 K St Ste 110',
#      'crossStreet': 'at 13th St',
#      'lat': 38.57836820811973,
#      'lng': -121.48970976158353,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57836820811973,
#        'lng': -121.48970976158353}],
#      'distance': 1104,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1215 K St Ste 110 (at 13th St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '5ca3b98398fbfc002c0cb4ae',
#     'name': 'Burnside Coffee Co',
#     'location': {'address': '701 16th St',
#      'lat': 38.58111,
#      'lng': -121.48361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58111,
#        'lng': -121.48361}],
#      'distance': 1584,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['701 16th St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '55295c95498e7f53857e91b7',
#     'name': 'Seasons Coffee',
#     'location': {'address': '1717 19th St Ste A',
#      'crossStreet': 'at Q St',
#      'lat': 38.568809509277344,
#      'lng': -121.48448944091797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.568809509277344,
#        'lng': -121.48448944091797}],
#      'distance': 2056,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1717 19th St Ste A (at Q St)',
#       'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4f32065519833175d60ad152',
#     'name': "Izzador's Organic Coffee and Tea",
#     'location': {'address': '2022 N St',
#      'lat': 38.571829,
#      'lng': -121.48107900000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.571829,
#        'lng': -121.48107900000001}],
#      'distance': 2093,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2022 N St', 'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4ed9c73e0e011b46edabdd87',
#     'name': 'Insight Coffee Roasters',
#     'location': {'address': '1901 8th St',
#      'crossStreet': 'at S St',
#      'lat': 38.57089650777213,
#      'lng': -121.500239982094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57089650777213,
#        'lng': -121.500239982094},
#       {'label': 'entrance', 'lat': 38.570912, 'lng': -121.50036}],
#      'distance': 1173,
#      'postalCode': '95811',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1901 8th St (at S St)', 'Sacramento, CA 95811']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4b6b2726f964a52029f62be3',
#     'name': 'House Kitchen & Bar',
#     'location': {'address': '555 Capitol Mall #155',
#      'crossStreet': 'at 5th St',
#      'lat': 38.57880478166184,
#      'lng': -121.50071542636849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.57880478166184,
#        'lng': -121.50071542636849},
#       {'label': 'entrance', 'lat': 38.578882, 'lng': -121.500737}],
#      'distance': 301,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['555 Capitol Mall #155 (at 5th St)',
#       'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90478997'},
#     'referralId': 'v-1617521556',
#     'hasPerk': False},
#    {'id': '4ba524bcf964a52044e338e3',
#     'name': 'Old Train Espresso & Smoothie',
#     'location': {'address': '904 2nd St',
#      'lat': 38.58413641573156,
#      'lng': -121.50389671325684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.58413641573156,
#        'lng': -121.50389671325684}],
#      'distance': 357,
#      'postalCode': '95814',
#      'cc': 'US',
#      'city': 'Sacramento',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['904 2nd St', 'Sacramento, CA 95814']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1617521556',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a _pandas_ dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                           id                                   name  \
# 0   4b5dbd50f964a5204d6929e3  Temple Coffee & Tea
# 1   528cddfc11d2c7ab7a3c9e61  Capitol Coffee
# 2   5a7f2b1b646e3832bf90475c  Camellia Coffee Roasters
# 3   5d6ea8b657ba4900081b5b77  Roots Coffee
# 4   5d335a7857c4ad00089607c5  Temple Coffee Roasters
# 5   507ed58ee4b0105cdae3110e  Shine - Coffee | Art | Music
# 6   4df7833d62e141c90764da81  Coffee Shoppe Building 171
# 7   4b0aff76f964a520522b23e3  Chocolate Fish Coffee Roasters
# 8   4c2f9c61ed37a59384976703  Pacha Coffee / Pachamama Coffee Co-op
# 9   4ad92c42f964a520d61821e3  Peet's Coffee & Tea
# 10  5fd50d4dae5d383597204583  Blueprint Coffee Project
# 11  553fd753498e429dca65be84  Turnaround Coffee House
# 12  4ec2da519adf5630f7182028  Amtrak Station Coffee & Snacks
# 13  4bc48ec32a89ef3b8e6df688  Beanheads Coffee Cart
# 14  556e164d498e044287137ee0  The Buzz Coffee Brewery
# 15  5d3c70fbb68ce90007214cff  Goodside Coffee
# 16  4f326c6919836c91c7d666a2  Coffee and More
# 17  571a5ec2498e9a18b2ea233e  Milka Coffee Roasters
# 18  59136bf55315932e7f2f6627  Oblivion Comics & Coffee
# 19  4d499ea119ab2d437a4eab95  Robot Coffee
# 20  4b589227f964a520c35e28e3  Chicory Coffee & Tea
# 21  5f5eeed2fd76be70ad33daf0  Scorpio Coffee
# 22  596e78d06a8d8610d1cce74d  Philz Coffee
# 23  54beab69498e7bffee036e59  Grace Coffee Roasters
# 24  5ca3b98398fbfc002c0cb4ae  Burnside Coffee Co
# 25  55295c95498e7f53857e91b7  Seasons Coffee
# 26  4f32065519833175d60ad152  Izzador's Organic Coffee and Tea
# 27  4ed9c73e0e011b46edabdd87  Insight Coffee Roasters
# 28  4b6b2726f964a52029f62be3  House Kitchen & Bar
# 29  4ba524bcf964a52044e338e3  Old Train Espresso & Smoothie
#
#                                                                                                                                                                                                                                                            categories  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 1   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 2   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 3   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 4   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 6   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 7   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 8   [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# 9   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 10  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 11  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 12  [{'id': '4bf58dd8d48988d129951735', 'name': 'Train Station', 'pluralName': 'Train Stations', 'shortName': 'Train Station', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_', 'suffix': '.png'}, 'primary': True}]
# 13  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}]
# 14  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 16  [{'id': '4d4b7105d754a06374d81259', 'name': 'Food', 'pluralName': 'Food', 'shortName': 'Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 17  [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# 18  [{'id': '52f2ab2ebcbc57f1066b8b18', 'name': 'Comic Shop', 'pluralName': 'Comic Shops', 'shortName': 'Comic Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_', 'suffix': '.png'}, 'primary': True}]
# 19  []
# 20  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 21  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 22  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 23  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 24  [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# 25  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 26  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 27  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 28  [{'id': '4bf58dd8d48988d157941735', 'name': 'New American Restaurant', 'pluralName': 'New American Restaurants', 'shortName': 'New American', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_', 'suffix': '.png'}, 'primary': True}]
# 29  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
#
#       referralId  hasPerk       location.address location.crossStreet  \
# 0   v-1617521556  False    1010 9th St            btwn J & K St
# 1   v-1617521556  False    1303 10th St           NaN
# 2   v-1617521556  False    1104 R St Ste 150      at 11th St
# 3   v-1617521556  False    428 J St Ste 120       at 5th St
# 4   v-1617521556  False    1615 16th St           at Powerhouse Aly
# 5   v-1617521556  False    1400 E St              at 14th St
# 6   v-1617521556  False    1501 Capitol Ave       NaN
# 7   v-1617521556  False    400 P St Ste 1203B     at 3rd & Q St
# 8   v-1617521556  False    919 20th St            btwn I & J St
# 9   v-1617521556  False    1050 20th St #190      at J St
# 10  v-1617521556  False    1200 2nd St            NaN
# 11  v-1617521556  False    724 7th St             NaN
# 12  v-1617521556  False    401 I St               at 5th St
# 13  v-1617521556  False    801 K St               NaN
# 14  v-1617521556  False    1121 L St              NaN
# 15  v-1617521556  False    1430 H St              at 15th St
# 16  v-1617521556  False    1515 R St              NaN
# 17  v-1617521556  False    1501 G St              at 15th St
# 18  v-1617521556  False    1020 11th St           btwn J & K St
# 19  v-1617521556  False    11th and C Streets     NaN
# 20  v-1617521556  False    1137 11th St           at L St
# 21  v-1617521556  False    1905 16th St           NaN
# 22  v-1617521556  False    1725 R St              at 17th St
# 23  v-1617521556  False    1215 K St Ste 110      at 13th St
# 24  v-1617521556  False    701 16th St            NaN
# 25  v-1617521556  False    1717 19th St Ste A     at Q St
# 26  v-1617521556  False    2022 N St              NaN
# 27  v-1617521556  False    1901 8th St            at S St
# 28  v-1617521556  False    555 Capitol Mall #155  at 5th St
# 29  v-1617521556  False    904 2nd St             NaN
#
#     location.lat  location.lng  \
# 0   38.580414    -121.495036
# 1   38.576790    -121.494827
# 2   38.570727    -121.495528
# 3   38.581802    -121.500380
# 4   38.570990    -121.488106
# 5   38.584107    -121.485427
# 6   38.575420    -121.487808
# 7   38.575068    -121.505985
# 8   38.577092    -121.479618
# 9   38.576585    -121.480161
# 10  38.580970    -121.505530
# 11  38.583981    -121.496758
# 12  38.584055    -121.500665
# 13  38.580054    -121.495798
# 14  38.577901    -121.492262
# 15  38.580525    -121.486273
# 16  38.569641    -121.489853
# 17  38.581822    -121.484842
# 18  38.579335    -121.492494
# 19  38.587105    -121.488876
# 20  38.577852    -121.492908
# 21  38.567838    -121.489368
# 22  38.568970    -121.487110
# 23  38.578368    -121.489710
# 24  38.581110    -121.483610
# 25  38.568810    -121.484489
# 26  38.571829    -121.481079
# 27  38.570897    -121.500240
# 28  38.578805    -121.500715
# 29  38.584136    -121.503897
#
#                                                                                                                        location.labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 38.58041379940968, 'lng': -121.49503550282543}]
# 1   [{'label': 'display', 'lat': 38.57678985595703, 'lng': -121.49482727050781}]
# 2   [{'label': 'display', 'lat': 38.57072738788299, 'lng': -121.49552822113036}]
# 3   [{'label': 'display', 'lat': 38.581802, 'lng': -121.50038}]
# 4   [{'label': 'display', 'lat': 38.57099, 'lng': -121.488106}]
# 5   [{'label': 'display', 'lat': 38.58410674401821, 'lng': -121.48542689451259}]
# 6   [{'label': 'display', 'lat': 38.57542037963867, 'lng': -121.48780822753906}]
# 7   [{'label': 'display', 'lat': 38.575067730078615, 'lng': -121.50598477403632}, {'label': 'entrance', 'lat': 38.575663, 'lng': -121.504729}]
# 8   [{'label': 'display', 'lat': 38.57709162976878, 'lng': -121.47961824533758}]
# 9   [{'label': 'display', 'lat': 38.576585, 'lng': -121.480161}, {'label': 'entrance', 'lat': 38.576177, 'lng': -121.480264}]
# 10  [{'label': 'display', 'lat': 38.58097, 'lng': -121.50553}]
# 11  [{'label': 'display', 'lat': 38.583980560302734, 'lng': -121.49675750732422}]
# 12  [{'label': 'display', 'lat': 38.58405543065516, 'lng': -121.50066488080698}]
# 13  [{'label': 'display', 'lat': 38.580054, 'lng': -121.495798}]
# 14  [{'label': 'display', 'lat': 38.577901000000004, 'lng': -121.49226200000001}]
# 15  [{'label': 'display', 'lat': 38.580525, 'lng': -121.486273}]
# 16  [{'label': 'display', 'lat': 38.56964111328125, 'lng': -121.48985290527344}]
# 17  [{'label': 'display', 'lat': 38.5818216608345, 'lng': -121.48484230041502}]
# 18  [{'label': 'display', 'lat': 38.57933470479946, 'lng': -121.49249406419403}]
# 19  [{'label': 'display', 'lat': 38.5871052312755, 'lng': -121.48887634277344}]
# 20  [{'label': 'display', 'lat': 38.577852437358736, 'lng': -121.49290770292282}]
# 21  [{'label': 'display', 'lat': 38.567838, 'lng': -121.489368}]
# 22  [{'label': 'display', 'lat': 38.56896952981297, 'lng': -121.48711040990693}]
# 23  [{'label': 'display', 'lat': 38.57836820811973, 'lng': -121.48970976158353}]
# 24  [{'label': 'display', 'lat': 38.58111, 'lng': -121.48361}]
# 25  [{'label': 'display', 'lat': 38.568809509277344, 'lng': -121.48448944091797}]
# 26  [{'label': 'display', 'lat': 38.571829, 'lng': -121.48107900000001}]
# 27  [{'label': 'display', 'lat': 38.57089650777213, 'lng': -121.500239982094}, {'label': 'entrance', 'lat': 38.570912, 'lng': -121.50036}]
# 28  [{'label': 'display', 'lat': 38.57880478166184, 'lng': -121.50071542636849}, {'label': 'entrance', 'lat': 38.578882, 'lng': -121.500737}]
# 29  [{'label': 'display', 'lat': 38.58413641573156, 'lng': -121.50389671325684}]
#
#     ...  location.state location.country  \
# 0   ...  CA              United States
# 1   ...  CA              United States
# 2   ...  CA              United States
# 3   ...  CA              United States
# 4   ...  CA              United States
# 5   ...  CA              United States
# 6   ...  CA              United States
# 7   ...  CA              United States
# 8   ...  CA              United States
# 9   ...  CA              United States
# 10  ...  CA              United States
# 11  ...  CA              United States
# 12  ...  CA              United States
# 13  ...  CA              United States
# 14  ...  CA              United States
# 15  ...  CA              United States
# 16  ...  CA              United States
# 17  ...  CA              United States
# 18  ...  CA              United States
# 19  ...  CA              United States
# 20  ...  CA              United States
# 21  ...  CA              United States
# 22  ...  CA              United States
# 23  ...  CA              United States
# 24  ...  CA              United States
# 25  ...  CA              United States
# 26  ...  CA              United States
# 27  ...  CA              United States
# 28  ...  CA              United States
# 29  ...  CA              United States
#
#                                      location.formattedAddress delivery.id  \
# 0   [1010 9th St (btwn J & K St), Sacramento, CA 95814]         NaN
# 1   [1303 10th St, Sacramento, CA 95814]                        NaN
# 2   [1104 R St Ste 150 (at 11th St), Sacramento, CA 95811]      NaN
# 3   [428 J St Ste 120 (at 5th St), Sacramento, CA 95814]        NaN
# 4   [1615 16th St (at Powerhouse Aly), Sacramento, CA 95814]    2040030
# 5   [1400 E St (at 14th St), Sacramento, CA 95814]              NaN
# 6   [1501 Capitol Ave, Sacramento, CA 95814]                    NaN
# 7   [400 P St Ste 1203B (at 3rd & Q St), Sacramento, CA 95814]  NaN
# 8   [919 20th St (btwn I & J St), Sacramento, CA 95811]         NaN
# 9   [1050 20th St #190 (at J St), Sacramento, CA 95811]         NaN
# 10  [1200 2nd St, Sacramento, CA 95814]                         NaN
# 11  [724 7th St, Sacramento, CA 95814]                          NaN
# 12  [401 I St (at 5th St), Sacramento, CA 95814]                NaN
# 13  [801 K St, Sacramento, CA 95814]                            NaN
# 14  [1121 L St, Sacramento, CA 95814]                           NaN
# 15  [1430 H St (at 15th St), Sacramento, CA 95814]              NaN
# 16  [1515 R St, Sacramento, CA 95811]                           NaN
# 17  [1501 G St (at 15th St), Sacramento, CA 95814]              NaN
# 18  [1020 11th St (btwn J & K St), Sacramento, CA 95814]        NaN
# 19  [11th and C Streets, Sacramento, CA 95814]                  NaN
# 20  [1137 11th St (at L St), Sacramento, CA 95814]              NaN
# 21  [1905 16th St, Sacramento, CA 95811]                        NaN
# 22  [1725 R St (at 17th St), Sacramento, CA 95811]              NaN
# 23  [1215 K St Ste 110 (at 13th St), Sacramento, CA 95814]      NaN
# 24  [701 16th St, Sacramento, CA 95814]                         NaN
# 25  [1717 19th St Ste A (at Q St), Sacramento, CA 95811]        NaN
# 26  [2022 N St, Sacramento, CA 95811]                           NaN
# 27  [1901 8th St (at S St), Sacramento, CA 95811]               NaN
# 28  [555 Capitol Mall #155 (at 5th St), Sacramento, CA 95814]   NaN
# 29  [904 2nd St, Sacramento, CA 95814]                          NaN
#
#                                                                                                                                                                                                    delivery.url  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   https://www.grubhub.com/restaurant/temple-coffee-roasters-1615-16th-st-sacramento/2040030?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2040030
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
#
#    delivery.provider.name             delivery.provider.icon.prefix  \
# 0   NaN                    NaN
# 1   NaN                    NaN
# 2   NaN                    NaN
# 3   NaN                    NaN
# 4   grubhub                https://fastly.4sqi.net/img/general/cap/
# 5   NaN                    NaN
# 6   NaN                    NaN
# 7   NaN                    NaN
# 8   NaN                    NaN
# 9   NaN                    NaN
# 10  NaN                    NaN
# 11  NaN                    NaN
# 12  NaN                    NaN
# 13  NaN                    NaN
# 14  NaN                    NaN
# 15  NaN                    NaN
# 16  NaN                    NaN
# 17  NaN                    NaN
# 18  NaN                    NaN
# 19  NaN                    NaN
# 20  NaN                    NaN
# 21  NaN                    NaN
# 22  NaN                    NaN
# 23  NaN                    NaN
# 24  NaN                    NaN
# 25  NaN                    NaN
# 26  NaN                    NaN
# 27  NaN                    NaN
# 28  NaN                    NaN
# 29  NaN                    NaN
#
#    delivery.provider.icon.sizes              delivery.provider.icon.name  \
# 0   NaN                          NaN
# 1   NaN                          NaN
# 2   NaN                          NaN
# 3   NaN                          NaN
# 4   [40, 50]                     /delivery_provider_grubhub_20180129.png
# 5   NaN                          NaN
# 6   NaN                          NaN
# 7   NaN                          NaN
# 8   NaN                          NaN
# 9   NaN                          NaN
# 10  NaN                          NaN
# 11  NaN                          NaN
# 12  NaN                          NaN
# 13  NaN                          NaN
# 14  NaN                          NaN
# 15  NaN                          NaN
# 16  NaN                          NaN
# 17  NaN                          NaN
# 18  NaN                          NaN
# 19  NaN                          NaN
# 20  NaN                          NaN
# 21  NaN                          NaN
# 22  NaN                          NaN
# 23  NaN                          NaN
# 24  NaN                          NaN
# 25  NaN                          NaN
# 26  NaN                          NaN
# 27  NaN                          NaN
# 28  NaN                          NaN
# 29  NaN                          NaN
#
#    venuePage.id
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   74683058
# 6   NaN
# 7   NaN
# 8   NaN
# 9   1359394722
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  90478997
# 29  NaN
#
# [30 rows x 25 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name               categories  \
# 0   Temple Coffee & Tea                    Coffee Shop
# 1   Capitol Coffee                         Coffee Shop
# 2   Camellia Coffee Roasters               Coffee Shop
# 3   Roots Coffee                           Coffee Shop
# 4   Temple Coffee Roasters                 Coffee Shop
# 5   Shine - Coffee | Art | Music           Coffee Shop
# 6   Coffee Shoppe Building 171             Coffee Shop
# 7   Chocolate Fish Coffee Roasters         Coffee Shop
# 8   Pacha Coffee / Pachamama Coffee Co-op  Café
# 9   Peet's Coffee & Tea                    Coffee Shop
# 10  Blueprint Coffee Project               Coffee Shop
# 11  Turnaround Coffee House                Coffee Shop
# 12  Amtrak Station Coffee & Snacks         Train Station
# 13  Beanheads Coffee Cart                  Food Truck
# 14  The Buzz Coffee Brewery                Coffee Shop
# 15  Goodside Coffee                        Coffee Shop
# 16  Coffee and More                        Food
# 17  Milka Coffee Roasters                  Café
# 18  Oblivion Comics & Coffee               Comic Shop
# 19  Robot Coffee                           None
# 20  Chicory Coffee & Tea                   Coffee Shop
# 21  Scorpio Coffee                         Coffee Shop
# 22  Philz Coffee                           Coffee Shop
# 23  Grace Coffee Roasters                  Coffee Shop
# 24  Burnside Coffee Co                     Café
# 25  Seasons Coffee                         Coffee Shop
# 26  Izzador's Organic Coffee and Tea       Coffee Shop
# 27  Insight Coffee Roasters                Coffee Shop
# 28  House Kitchen & Bar                    New American Restaurant
# 29  Old Train Espresso & Smoothie          Coffee Shop
#
#                   address        crossStreet        lat         lng  \
# 0   1010 9th St            btwn J & K St      38.580414 -121.495036
# 1   1303 10th St           NaN                38.576790 -121.494827
# 2   1104 R St Ste 150      at 11th St         38.570727 -121.495528
# 3   428 J St Ste 120       at 5th St          38.581802 -121.500380
# 4   1615 16th St           at Powerhouse Aly  38.570990 -121.488106
# 5   1400 E St              at 14th St         38.584107 -121.485427
# 6   1501 Capitol Ave       NaN                38.575420 -121.487808
# 7   400 P St Ste 1203B     at 3rd & Q St      38.575068 -121.505985
# 8   919 20th St            btwn I & J St      38.577092 -121.479618
# 9   1050 20th St #190      at J St            38.576585 -121.480161
# 10  1200 2nd St            NaN                38.580970 -121.505530
# 11  724 7th St             NaN                38.583981 -121.496758
# 12  401 I St               at 5th St          38.584055 -121.500665
# 13  801 K St               NaN                38.580054 -121.495798
# 14  1121 L St              NaN                38.577901 -121.492262
# 15  1430 H St              at 15th St         38.580525 -121.486273
# 16  1515 R St              NaN                38.569641 -121.489853
# 17  1501 G St              at 15th St         38.581822 -121.484842
# 18  1020 11th St           btwn J & K St      38.579335 -121.492494
# 19  11th and C Streets     NaN                38.587105 -121.488876
# 20  1137 11th St           at L St            38.577852 -121.492908
# 21  1905 16th St           NaN                38.567838 -121.489368
# 22  1725 R St              at 17th St         38.568970 -121.487110
# 23  1215 K St Ste 110      at 13th St         38.578368 -121.489710
# 24  701 16th St            NaN                38.581110 -121.483610
# 25  1717 19th St Ste A     at Q St            38.568810 -121.484489
# 26  2022 N St              NaN                38.571829 -121.481079
# 27  1901 8th St            at S St            38.570897 -121.500240
# 28  555 Capitol Mall #155  at 5th St          38.578805 -121.500715
# 29  904 2nd St             NaN                38.584136 -121.503897
#
#                                                                                                                                 labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 38.58041379940968, 'lng': -121.49503550282543}]
# 1   [{'label': 'display', 'lat': 38.57678985595703, 'lng': -121.49482727050781}]
# 2   [{'label': 'display', 'lat': 38.57072738788299, 'lng': -121.49552822113036}]
# 3   [{'label': 'display', 'lat': 38.581802, 'lng': -121.50038}]
# 4   [{'label': 'display', 'lat': 38.57099, 'lng': -121.488106}]
# 5   [{'label': 'display', 'lat': 38.58410674401821, 'lng': -121.48542689451259}]
# 6   [{'label': 'display', 'lat': 38.57542037963867, 'lng': -121.48780822753906}]
# 7   [{'label': 'display', 'lat': 38.575067730078615, 'lng': -121.50598477403632}, {'label': 'entrance', 'lat': 38.575663, 'lng': -121.504729}]
# 8   [{'label': 'display', 'lat': 38.57709162976878, 'lng': -121.47961824533758}]
# 9   [{'label': 'display', 'lat': 38.576585, 'lng': -121.480161}, {'label': 'entrance', 'lat': 38.576177, 'lng': -121.480264}]
# 10  [{'label': 'display', 'lat': 38.58097, 'lng': -121.50553}]
# 11  [{'label': 'display', 'lat': 38.583980560302734, 'lng': -121.49675750732422}]
# 12  [{'label': 'display', 'lat': 38.58405543065516, 'lng': -121.50066488080698}]
# 13  [{'label': 'display', 'lat': 38.580054, 'lng': -121.495798}]
# 14  [{'label': 'display', 'lat': 38.577901000000004, 'lng': -121.49226200000001}]
# 15  [{'label': 'display', 'lat': 38.580525, 'lng': -121.486273}]
# 16  [{'label': 'display', 'lat': 38.56964111328125, 'lng': -121.48985290527344}]
# 17  [{'label': 'display', 'lat': 38.5818216608345, 'lng': -121.48484230041502}]
# 18  [{'label': 'display', 'lat': 38.57933470479946, 'lng': -121.49249406419403}]
# 19  [{'label': 'display', 'lat': 38.5871052312755, 'lng': -121.48887634277344}]
# 20  [{'label': 'display', 'lat': 38.577852437358736, 'lng': -121.49290770292282}]
# 21  [{'label': 'display', 'lat': 38.567838, 'lng': -121.489368}]
# 22  [{'label': 'display', 'lat': 38.56896952981297, 'lng': -121.48711040990693}]
# 23  [{'label': 'display', 'lat': 38.57836820811973, 'lng': -121.48970976158353}]
# 24  [{'label': 'display', 'lat': 38.58111, 'lng': -121.48361}]
# 25  [{'label': 'display', 'lat': 38.568809509277344, 'lng': -121.48448944091797}]
# 26  [{'label': 'display', 'lat': 38.571829, 'lng': -121.48107900000001}]
# 27  [{'label': 'display', 'lat': 38.57089650777213, 'lng': -121.500239982094}, {'label': 'entrance', 'lat': 38.570912, 'lng': -121.50036}]
# 28  [{'label': 'display', 'lat': 38.57880478166184, 'lng': -121.50071542636849}, {'label': 'entrance', 'lat': 38.578882, 'lng': -121.500737}]
# 29  [{'label': 'display', 'lat': 38.58413641573156, 'lng': -121.50389671325684}]
#
#     distance postalCode  cc         neighborhood        city state  \
# 0   599       95814      US  Downtown Sacramento  Sacramento  CA
# 1   793       95814      US  NaN                  Sacramento  CA
# 2   1304      95811      US  NaN                  Sacramento  CA
# 3   133       95814      US  NaN                  Sacramento  CA
# 4   1660      95814      US  NaN                  Sacramento  CA
# 5   1457      95814      US  NaN                  Sacramento  CA
# 6   1386      95814      US  NaN                  Sacramento  CA
# 7   790       95814      US  NaN                  Sacramento  CA
# 8   1989      95811      US  NaN                  Sacramento  CA
# 9   1957      95811      US  NaN                  Sacramento  CA
# 10  326       95814      US  NaN                  Sacramento  CA
# 11  527       95814      US  NaN                  Sacramento  CA
# 12  315       95814      US  NaN                  Sacramento  CA
# 13  543       95814      US  NaN                  Sacramento  CA
# 14  916       95814      US  NaN                  Sacramento  CA
# 15  1355      95814      US  NaN                  Sacramento  CA
# 16  1669      95811      US  NaN                  Sacramento  CA
# 17  1477      95814      US  NaN                  Sacramento  CA
# 18  841       95814      US  NaN                  Sacramento  CA
# 19  1293      95814      US  NaN                  Sacramento  CA
# 20  868       95814      US  Downtown Sacramento  Sacramento  CA
# 21  1855      95811      US  NaN                  Sacramento  CA
# 22  1882      95811      US  NaN                  Sacramento  CA
# 23  1104      95814      US  NaN                  Sacramento  CA
# 24  1584      95814      US  NaN                  Sacramento  CA
# 25  2056      95811      US  NaN                  Sacramento  CA
# 26  2093      95811      US  NaN                  Sacramento  CA
# 27  1173      95811      US  NaN                  Sacramento  CA
# 28  301       95814      US  NaN                  Sacramento  CA
# 29  357       95814      US  NaN                  Sacramento  CA
#
#           country                                            formattedAddress  \
# 0   United States  [1010 9th St (btwn J & K St), Sacramento, CA 95814]
# 1   United States  [1303 10th St, Sacramento, CA 95814]
# 2   United States  [1104 R St Ste 150 (at 11th St), Sacramento, CA 95811]
# 3   United States  [428 J St Ste 120 (at 5th St), Sacramento, CA 95814]
# 4   United States  [1615 16th St (at Powerhouse Aly), Sacramento, CA 95814]
# 5   United States  [1400 E St (at 14th St), Sacramento, CA 95814]
# 6   United States  [1501 Capitol Ave, Sacramento, CA 95814]
# 7   United States  [400 P St Ste 1203B (at 3rd & Q St), Sacramento, CA 95814]
# 8   United States  [919 20th St (btwn I & J St), Sacramento, CA 95811]
# 9   United States  [1050 20th St #190 (at J St), Sacramento, CA 95811]
# 10  United States  [1200 2nd St, Sacramento, CA 95814]
# 11  United States  [724 7th St, Sacramento, CA 95814]
# 12  United States  [401 I St (at 5th St), Sacramento, CA 95814]
# 13  United States  [801 K St, Sacramento, CA 95814]
# 14  United States  [1121 L St, Sacramento, CA 95814]
# 15  United States  [1430 H St (at 15th St), Sacramento, CA 95814]
# 16  United States  [1515 R St, Sacramento, CA 95811]
# 17  United States  [1501 G St (at 15th St), Sacramento, CA 95814]
# 18  United States  [1020 11th St (btwn J & K St), Sacramento, CA 95814]
# 19  United States  [11th and C Streets, Sacramento, CA 95814]
# 20  United States  [1137 11th St (at L St), Sacramento, CA 95814]
# 21  United States  [1905 16th St, Sacramento, CA 95811]
# 22  United States  [1725 R St (at 17th St), Sacramento, CA 95811]
# 23  United States  [1215 K St Ste 110 (at 13th St), Sacramento, CA 95814]
# 24  United States  [701 16th St, Sacramento, CA 95814]
# 25  United States  [1717 19th St Ste A (at Q St), Sacramento, CA 95811]
# 26  United States  [2022 N St, Sacramento, CA 95811]
# 27  United States  [1901 8th St (at S St), Sacramento, CA 95811]
# 28  United States  [555 Capitol Mall #155 (at 5th St), Sacramento, CA 95814]
# 29  United States  [904 2nd St, Sacramento, CA 95814]
#
#                           id
# 0   4b5dbd50f964a5204d6929e3
# 1   528cddfc11d2c7ab7a3c9e61
# 2   5a7f2b1b646e3832bf90475c
# 3   5d6ea8b657ba4900081b5b77
# 4   5d335a7857c4ad00089607c5
# 5   507ed58ee4b0105cdae3110e
# 6   4df7833d62e141c90764da81
# 7   4b0aff76f964a520522b23e3
# 8   4c2f9c61ed37a59384976703
# 9   4ad92c42f964a520d61821e3
# 10  5fd50d4dae5d383597204583
# 11  553fd753498e429dca65be84
# 12  4ec2da519adf5630f7182028
# 13  4bc48ec32a89ef3b8e6df688
# 14  556e164d498e044287137ee0
# 15  5d3c70fbb68ce90007214cff
# 16  4f326c6919836c91c7d666a2
# 17  571a5ec2498e9a18b2ea233e
# 18  59136bf55315932e7f2f6627
# 19  4d499ea119ab2d437a4eab95
# 20  4b589227f964a520c35e28e3
# 21  5f5eeed2fd76be70ad33daf0
# 22  596e78d06a8d8610d1cce74d
# 23  54beab69498e7bffee036e59
# 24  5ca3b98398fbfc002c0cb4ae
# 25  55295c95498e7f53857e91b7
# 26  4f32065519833175d60ad152
# 27  4ed9c73e0e011b46edabdd87
# 28  4b6b2726f964a52029f62be3
# 29  4ba524bcf964a52044e338e3

# %% [markdown]
# #### Let's visualize the Coffee shops that are nearby

# %%
dataframe_filtered.name
# Out:
# 0     Temple Coffee & Tea
# 1     Capitol Coffee
# 2     Camellia Coffee Roasters
# 3     Roots Coffee
# 4     Temple Coffee Roasters
# 5     Shine - Coffee | Art | Music
# 6     Coffee Shoppe Building 171
# 7     Chocolate Fish Coffee Roasters
# 8     Pacha Coffee / Pachamama Coffee Co-op
# 9     Peet's Coffee & Tea
# 10    Blueprint Coffee Project
# 11    Turnaround Coffee House
# 12    Amtrak Station Coffee & Snacks
# 13    Beanheads Coffee Cart
# 14    The Buzz Coffee Brewery
# 15    Goodside Coffee
# 16    Coffee and More
# 17    Milka Coffee Roasters
# 18    Oblivion Comics & Coffee
# 19    Robot Coffee
# 20    Chicory Coffee & Tea
# 21    Scorpio Coffee
# 22    Philz Coffee
# 23    Grace Coffee Roasters
# 24    Burnside Coffee Co
# 25    Seasons Coffee
# 26    Izzador's Organic Coffee and Tea
# 27    Insight Coffee Roasters
# 28    House Kitchen & Bar
# 29    Old Train Espresso & Smoothie
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_19a272626ded498d917411fcc43ed5d4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_19a272626ded498d917411fcc43ed5d4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_19a272626ded498d917411fcc43ed5d4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_19a272626ded498d917411fcc43ed5d4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.58137029292929%2C%20-121.50181023232324%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %%
venue_id = '4b5dbd50f964a5204d6929e3' # ID of Temple COffee, one of my favorites
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b5dbd50f964a5204d6929e3?client_id=AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1&client_secret=XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL&oauth_token=JVP0CYFI0X1O2S21N44G1I303FDAJBY1ZJUI0X0YRVLVJQRE&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b5dbd50f964a5204d6929e3',
#  'name': 'Temple Coffee & Tea',
#  'contact': {'phone': '9164434960',
#   'formattedPhone': '(916) 443-4960',
#   'twitter': 'templecoffee',
#   'facebook': '115977378424236',
#   'facebookName': 'Temple'},
#  'location': {'address': '1010 9th St',
#   'crossStreet': 'btwn J & K St',
#   'lat': 38.58041379940968,
#   'lng': -121.49503550282543,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 38.58041379940968,
#     'lng': -121.49503550282543}],
#   'postalCode': '95814',
#   'cc': 'US',
#   'neighborhood': 'Downtown Sacramento',
#   'city': 'Sacramento',
#   'state': 'CA',
#   'country': 'United States',
#   'formattedAddress': ['1010 9th St (btwn J & K St)', 'Sacramento, CA 95814']},
#  'canonicalUrl': 'https://foursquare.com/v/temple-coffee--tea/4b5dbd50f964a5204d6929e3',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d16d941735',
#    'name': 'Café',
#    'pluralName': 'Cafés',
#    'shortName': 'Café',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 72},
#  'url': 'http://templecoffee.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 193,
#   'groups': [{'type': 'others', 'count': 193, 'items': []}],
#   'summary': '193 Likes'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'rating': 8.8,
#  'ratingColor': '73CF42',
#  'ratingSignals': 262,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/temple-coffee--tea/4b5dbd50f964a5204d6929e3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4b5dbd50f964a5204d6929e3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 242,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 242,
#     'items': [{'id': '503acd14e4b0fd37184186f0',
#       'createdAt': 1346030868,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/tzPVXFYN_A003_loVleX_wF9PaqpC4TePFL5JYb2RO8.jpg',
#       'width': 720,
#       'height': 540,
#       'user': {'id': '29560726',
#        'firstName': 'Travis',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/XPEOXR32N4IBDNQW.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'A light-filled, airy cafe with an open floor plan that features ample seating, hand-made 13-foot communal tables and a pour over bar, Temple Downtown is centrally located, just a convenient couple of blocks from both City Hall and the State Capitol. Open every day of the year.',
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1264434512,
#  'tips': {'count': 72,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 72,
#     'items': [{'id': '4e8b9a65d22db1c42af601d7',
#       'createdAt': 1317771877,
#       'text': 'Every expresso is made with care, even the room humidity is considered. Drink expresso here to develop your fine coffee palette.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4e8b9a65d22db1c42af601d7',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others',
#          'count': 4,
#          'items': [{'id': '12404929',
#            'firstName': 'Chi',
#            'lastName': 'Hatcher',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/12404929-AOKCCMI4IKJN0SJG.jpg'}},
#           {'id': '39740488',
#            'firstName': 'Kimmi',
#            'lastName': 'Merritt',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/3QBR31BUM24V3YV0.jpg'}},
#           {'id': '29484540',
#            'firstName': 'Bunny',
#            'lastName': 'Zlotnik',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/UW5KACX0MSSINVDR.jpg'}}]}],
#        'summary': '4 likes'},
#       'like': False,
#       'logView': True,
#       'agreeCount': 3,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '13290705',
#        'firstName': 'J',
#        'lastName': 'Roudebush',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W5NLO1KZJ045ASJS.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/bmd5ty',
#  'timeZone': 'America/Los_Angeles',
#  'listed': {'count': 129,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 129,
#     'items': [{'id': '4f6aa442e4b0b8a882af321b',
#       'name': '/r/coffee',
#       'description': 'The best coffee shops on earth, all in one list.\n\nTo the redditors of /r/coffee just add me as a friend and you can add your own favorite places. I envision this as a list for third wave coffee shops.',
#       'type': 'others',
#       'user': {'id': '5807821',
#        'firstName': 'Jason',
#        'lastName': 'Pope',
#        'gender': 'none',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/03ZLJGPHPJIHI5PA.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/cowholio4/list/rcoffee',
#       'canonicalUrl': 'https://foursquare.com/cowholio4/list/rcoffee',
#       'createdAt': 1332388930,
#       'updatedAt': 1509557157,
#       'photo': {'id': '4f0f20b7e4b0129c74ae8b4f',
#        'createdAt': 1326391479,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0FMDYBCT5H5EPHZCECRKN3WQCLLKMMXMCCAHPZWB1KAPPFVH.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '5807821',
#         'firstName': 'Jason',
#         'lastName': 'Pope',
#         'gender': 'none',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/03ZLJGPHPJIHI5PA.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 159},
#       'listItems': {'count': 212,
#        'items': [{'id': 'v4b5dbd50f964a5204d6929e3',
#          'createdAt': 1381199481}]}},
#      {'id': '4ed13112b8f7971d6b918a4b',
#       'name': 'Work',
#       'description': 'Places around the world that have a great vibe, good WiFi and a power outlet or two. I work on the road most of the time and these places have made it easier.',
#       'type': 'others',
#       'user': {'id': '1527',
#        'firstName': 'Andrew',
#        'lastName': 'Cafourek',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1527-L1C21G5HXDNONE4B'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/acafourek/list/work',
#       'canonicalUrl': 'https://foursquare.com/acafourek/list/work',
#       'createdAt': 1322332434,
#       'updatedAt': 1570135096,
#       'photo': {'id': '51c4d278498eee491870f6c9',
#        'createdAt': 1371853432,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1025924_5jqCK6jNArHYgnrKrnpqb0CbIt8OwrWdbl6UXndhsz8.jpg',
#        'width': 720,
#        'height': 720,
#        'user': {'id': '1025924',
#         'firstName': 'Manny',
#         'lastName': 'Gonzalez',
#         'gender': 'male',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/ZEWIJIIHAZMROXR1.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 28},
#       'listItems': {'count': 256,
#        'items': [{'id': 'v4b5dbd50f964a5204d6929e3',
#          'createdAt': 1377553738}]}}]}]},
#  'hours': {'status': 'Closed until 6:00 AM',
#   'richStatus': {'entities': [], 'text': 'Closed until 6:00 AM'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '6:00 AM–6:00 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–4:00 PM'},
#      {'renderedTime': '9:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–6:00 PM'},
#      {'renderedTime': '9:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–6:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Closed until 6:00 AM',
#   'richStatus': {'entities': [], 'text': 'Closed until 6:00 AM'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '6:00 AM–6:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Breakfast',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'}]}]},
#  'bestPhoto': {'id': '503acd14e4b0fd37184186f0',
#   'createdAt': 1346030868,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/tzPVXFYN_A003_loVleX_wF9PaqpC4TePFL5JYb2RO8.jpg',
#   'width': 720,
#   'height': 540,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '503acd14e4b0fd37184186f0',
#    'value': -3100568},
#   'highlightTextColor': {'photoId': '503acd14e4b0fd37184186f0',
#    'value': -16777216},
#   'algoVersion': 3}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.8

# %% [markdown]
# Reflects Temple, Temple is pretty good.

# %%
venue_id = '59136bf55315932e7f2f6627' # ID of Oblivion Comics and Coffee
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.1

# %% [markdown]
# Oblivion has lower rating.

# %%
venue_id = '4ed9c73e0e011b46edabdd87' # ID of Insight
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %% [markdown]
# Insight is similar to Temple's rating.

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 44

# %% [markdown]
# ### D. Get the venue's tips
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Create URL and send GET request. Make sure to set limit to get all tips

# %%
## Insight Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '606968de1a54077653c9bca0'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'tips': {'count': 44,
#    'items': [{'id': '55768aeb498e5007f2b0a608',
#      'createdAt': 1433832171,
#      'text': 'One of my favorite new coffee shops in Sacramento! The space is beautiful and open. Plenty of seating for meeting up with others or working by yourself. Overlooks a park. The coffee is delicious!',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/55768aeb498e5007f2b0a608',
#      'photo': {'id': '55768aeb498e5007f2b0a607',
#       'createdAt': 1433832171,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/47157589_3MmbzoffzhQfwVfk576IcsJppr6XDexKo5vArW35XlI.jpg',
#       'width': 640,
#       'height': 640,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/47157589_3MmbzoffzhQfwVfk576IcsJppr6XDexKo5vArW35XlI.jpg',
#      'likes': {'count': 0, 'groups': []},
#      'like': False,
#      'logView': True,
#      'agreeCount': 1,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '47157589',
#       'firstName': 'JaredWhite.Realtor',
#       'lastName': 'Sacramento',
#       'gender': 'male',
#       'countryCode': 'US',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/47157589-14FNFKHKMPNZW3RT'}},
#      'authorInteractionType': 'liked'}]}}}

# %% [markdown]
# #### Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %% [markdown]
# #### Format column width and display all tips

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                                                                                                                                   text  \
# 0  One of my favorite new coffee shops in Sacramento! The space is beautiful and open. Plenty of seating for meeting up with others or working by yourself. Overlooks a park. The coffee is delicious!
#
#    agreeCount  disagreeCount                        id      user.firstName  \
# 0  1           0              55768aeb498e5007f2b0a608  JaredWhite.Realtor
#
#   user.lastName   user.id
# 0  Sacramento    47157589

# %% [markdown]
# Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 15 tips.

# %% [markdown]
# <a id="item3"></a>

# %% [markdown]
# #### Let's explore competitor coffee places nearby insight.

# %%
latitude = 38.570897
longitude = -121.500240

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=AZ5B451IML2PEU4AYQMWH4BYBBK0VAGE1XW405VDD5ARZHE1&client_secret=XVOXZOF1RIHDFX0RIQHNXQEIL1NXXDDF4CWLNC352WDCEPHL&ll=38.570897,-121.50024&v=20180604&radius=2000&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Insight Coffee.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Insight Coffee.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5452ad26498e2e8f461d877b',
#   'name': 'South',
#   'location': {'address': '2005 11th St',
#    'lat': 38.56866546458417,
#    'lng': -121.49696172964893,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 38.56866546458417,
#      'lng': -121.49696172964893}],
#    'distance': 378,
#    'postalCode': '95818',
#    'cc': 'US',
#    'city': 'Sacramento',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['2005 11th St',
#     'Sacramento, CA 95818',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14f941735',
#     'name': 'Southern / Soul Food Restaurant',
#     'pluralName': 'Southern / Soul Food Restaurants',
#     'shortName': 'Southern / Soul',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-5452ad26498e2e8f461d877b-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                  name                       categories  \
# 0  South                               Southern / Soul Food Restaurant
# 1  Insight Coffee Roasters             Coffee Shop
# 2  Bottle & Barlow                     Salon / Barbershop
# 3  Beers Books                         Bookstore
# 4  Fox & Goose Public House            Pub
# 5  Osaka Ya                            Dessert Shop
# 6  Sacramento Central Farmers' Market  Farmers Market
# 7  WAL Public Market                   Market
# 8  Urban Roots Brewing & Smokehouse    Brewery
# 9  Crocker Art Museum                  Art Museum
#
#         address        lat         lng  \
# 0  2005 11th St  38.568665 -121.496962
# 1  1901 8th St   38.570897 -121.500240
# 2  1120 R St     38.570889 -121.494917
# 3  915 S St      38.570570 -121.498237
# 4  1001 R St     38.571523 -121.496936
# 5  2215 10th St  38.566629 -121.499358
# 6  W St          38.566522 -121.503779
# 7  1104 R St     38.570887 -121.495573
# 8  1322 V St     38.565530 -121.494032
# 9  216 O St      38.577379 -121.506715
#
#                                                                                                                                labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 38.56866546458417, 'lng': -121.49696172964893}]
# 1  [{'label': 'display', 'lat': 38.57089650777213, 'lng': -121.500239982094}, {'label': 'entrance', 'lat': 38.570912, 'lng': -121.50036}]
# 2  [{'label': 'display', 'lat': 38.57088867970689, 'lng': -121.49491687697576}]
# 3  [{'label': 'display', 'lat': 38.57057022273445, 'lng': -121.49823691257343}]
# 4  [{'label': 'display', 'lat': 38.571523421273845, 'lng': -121.49693617055989}]
# 5  [{'label': 'display', 'lat': 38.56662880215227, 'lng': -121.49935790816711}, {'label': 'entrance', 'lat': 38.566591, 'lng': -121.499267}]
# 6  [{'label': 'display', 'lat': 38.56652227452419, 'lng': -121.50377869606018}]
# 7  [{'label': 'display', 'lat': 38.57088747438397, 'lng': -121.49557334121658}]
# 8  [{'label': 'display', 'lat': 38.565529878660605, 'lng': -121.49403206067002}, {'label': 'entrance', 'lat': 38.565476, 'lng': -121.493961}]
# 9  [{'label': 'display', 'lat': 38.577378565419494, 'lng': -121.50671535360972}]
#
#    distance postalCode  cc        city state        country  \
# 0  378       95818      US  Sacramento  CA    United States
# 1  0         95811      US  Sacramento  CA    United States
# 2  463       95811      US  Sacramento  CA    United States
# 3  178       95811      US  Sacramento  CA    United States
# 4  295       95811      US  Sacramento  CA    United States
# 5  481       95818      US  Sacramento  CA    United States
# 6  576       95818      US  Sacramento  CA    United States
# 7  406       95811      US  Sacramento  CA    United States
# 8  805       95818      US  Sacramento  CA    United States
# 9  915       95814      US  Sacramento  CA    United States
#
#                                                        formattedAddress  \
# 0  [2005 11th St, Sacramento, CA 95818, United States]
# 1  [1901 8th St (at S St), Sacramento, CA 95811, United States]
# 2  [1120 R St (at 12th St), Sacramento, CA 95811, United States]
# 3  [915 S St (btwn 9th & 10th St), Sacramento, CA 95811, United States]
# 4  [1001 R St (at 10th St), Sacramento, CA 95811, United States]
# 5  [2215 10th St (btwn V & W St), Sacramento, CA 95818, United States]
# 6  [W St (btwn 6th & 8th St), Sacramento, CA 95818, United States]
# 7  [1104 R St (at 11th St), Sacramento, CA 95811, United States]
# 8  [1322 V St, Sacramento, CA 95818, United States]
# 9  [216 O St (at 2nd St), Sacramento, CA 95814, United States]
#
#           crossStreet        neighborhood                        id
# 0  NaN                 NaN                 5452ad26498e2e8f461d877b
# 1  at S St             NaN                 4ed9c73e0e011b46edabdd87
# 2  at 12th St          NaN                 555e4fc2498e2877db2bd0e1
# 3  btwn 9th & 10th St  NaN                 4b173c21f964a5200bc423e3
# 4  at 10th St          NaN                 4b0586b4f964a5208b6a22e3
# 5  btwn V & W St       NaN                 4b683b2cf964a520266d2be3
# 6  btwn 6th & 8th St   NaN                 4b37a9e7f964a520df4325e3
# 7  at 11th St          NaN                 559f2c9c498e71462291c6fc
# 8  NaN                 Central Sacramento  5a444c558173cb3a047ae53d
# 9  at 2nd St           NaN                 4b0586b7f964a520ee6a22e3

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dccb4facaf2b423f86c145e4a1528516%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dccb4facaf2b423f86c145e4a1528516%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dccb4facaf2b423f86c145e4a1528516%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dccb4facaf2b423f86c145e4a1528516%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.570897%2C%20-121.50024%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
#
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Let's look at trending places around Insight Coffee.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60696a5cf48cf454910847f1'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# <a id="item6"></a>

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!
#
# This notebook modified by Nayef Abou Tayoun ([https://www.linkedin.com/in/nayefaboutayoun/](https://www.linkedin.com/in/nayefaboutayoun?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ))

# %% [markdown]
# This notebook is part of a course on **Coursera** called _Applied Data Science Capstone_. If you accessed this notebook outside the course, you can take this course online by clicking [here](http://cocl.us/DP0701EN_Coursera_Week2_LAB1).

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description         |
# | ----------------- | ------- | ------------- | -------------------------- |
# | 2020-11-26        | 2.0     | Lakshmi Holla | Updated the markdown cells |
# |                   |         |               |                            |
# |                   |         |               |                            |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
